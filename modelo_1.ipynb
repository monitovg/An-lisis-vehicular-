# %% [markdown]
# # Modelo 1 (Random Forest)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from ydata_profiling import ProfileReport
import sklearn
import datetime

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn import set_config
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, roc_curve, auc

from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score, f1_score, classification_report

# %%
data = pd.read_csv("data.csv")
data
# Out:
#          Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0         BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1         BMW    1 Series  2011     premium unleaded (required)      300.0
# 2         BMW    1 Series  2011     premium unleaded (required)      300.0
# 3         BMW    1 Series  2011     premium unleaded (required)      230.0
# 4         BMW    1 Series  2011     premium unleaded (required)      230.0
# ...       ...         ...   ...                             ...        ...
# 8079    Acura         ZDX  2012     premium unleaded (required)      300.0
# 8080    Acura         ZDX  2012     premium unleaded (required)      300.0
# 8081    Acura         ZDX  2012     premium unleaded (required)      300.0
# 8082    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 8083  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                  6.0            MANUAL   rear wheel drive              2.0
# 1                  6.0            MANUAL   rear wheel drive              2.0
# 2                  6.0            MANUAL   rear wheel drive              2.0
# 3                  6.0            MANUAL   rear wheel drive              2.0
# 4                  6.0            MANUAL   rear wheel drive              2.0
# ...                ...               ...                ...              ...
# 8079               6.0         AUTOMATIC    all wheel drive              4.0
# 8080               6.0         AUTOMATIC    all wheel drive              4.0
# 8081               6.0         AUTOMATIC    all wheel drive              4.0
# 8082               6.0         AUTOMATIC    all wheel drive              4.0
# 8083               6.0         AUTOMATIC  front wheel drive              4.0
#
#                             Market Category Vehicle Size  Vehicle Style  \
# 0     Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                        Luxury,Performance      Compact    Convertible
# 2                   Luxury,High-Performance      Compact          Coupe
# 3                        Luxury,Performance      Compact          Coupe
# 4                                    Luxury      Compact    Convertible
# ...                                     ...          ...            ...
# 8079             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 8080             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 8081             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 8082             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 8083                                 Luxury      Midsize          Sedan
#
#       highway MPG  city mpg  Popularity   MSRP
# 0              26        19        3916  46135
# 1              28        19        3916  40650
# 2              28        20        3916  36350
# 3              28        18        3916  29450
# 4              28        18        3916  34500
# ...           ...       ...         ...    ...
# 8079           23        16         204  46120
# 8080           23        16         204  56670
# 8081           23        16         204  50620
# 8082           23        16         204  50920
# 8083           26        17          61  28995
#
# [8084 rows x 16 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# %%
data.loc[:, 'Popularity'] = data['Popularity'].astype(int)
X = data.drop('Popularity', axis=1)
y = data['Popularity']
X = pd.get_dummies(X)
makes = data['Make']
X_train, X_test, y_train, y_test, makes_train, makes_test = train_test_split(X, y, makes, test_size=0.2, random_state=42, stratify=y)

rf = RandomForestClassifier(random_state=42)

rf_param_distributions = {
    'n_estimators': [100, 200],
    'max_features': [None, 'sqrt', 'log2'],
    'max_depth': [10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1],
    'bootstrap': [True]
}

rf_random_search = RandomizedSearchCV(estimator=rf, param_distributions=rf_param_distributions,
                                      n_iter=10, cv=2, verbose=2, random_state=42, n_jobs=-1)

rf_random_search.fit(X_train, y_train)
best_rf = rf_random_search.best_estimator_

y_pred_rf = best_rf.predict(X_test)
print("Random Forest con mejores Hiperparametros:")
print(f"Exactitud: {accuracy_score(y_test, y_pred_rf)}")
print(classification_report(y_test, y_pred_rf))

results_rf = pd.DataFrame({'Make': makes_test, 'Predicted_Popularity': y_pred_rf})

avg_popularity_rf = results_rf.groupby('Make')['Predicted_Popularity'].mean().reset_index()

top_make_rf = avg_popularity_rf.loc[avg_popularity_rf['Predicted_Popularity'].idxmax()]

print("Mejor marca según Random Forest:")
print(top_make_rf)
avg_popularity_rf_sorted = avg_popularity_rf.sort_values(by='Predicted_Popularity', ascending=False)

top_3_makes_rf = avg_popularity_rf_sorted.head(3)
print("Tres marcas más populares según Random Forest:")
print(top_3_makes_rf)
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# Random Forest con mejores Hiperparametros:
# Exactitud: 1.0
#               precision    recall  f1-score   support
#
#            2       1.00      1.00      1.00         1
#           26       1.00      1.00      1.00         1
#           61       1.00      1.00      1.00        31
#           67       1.00      1.00      1.00         3
#           86       1.00      1.00      1.00         6
#          105       1.00      1.00      1.00        10
#          113       1.00      1.00      1.00         1
#          130       1.00      1.00      1.00         3
#          155       1.00      1.00      1.00        25
#          190       1.00      1.00      1.00        66
#          204       1.00      1.00      1.00        50
#          210       1.00      1.00      1.00        15
#          238       1.00      1.00      1.00        12
#          258       1.00      1.00      1.00        29
#          259       1.00      1.00      1.00        19
#          376       1.00      1.00      1.00        22
#          416       1.00      1.00      1.00         1
#          436       1.00      1.00      1.00        25
#          454       1.00      1.00      1.00        40
#          481       1.00      1.00      1.00        20
#          520       1.00      1.00      1.00        15
#          535       1.00      1.00      1.00         8
#          549       1.00      1.00      1.00        54
#          586       1.00      1.00      1.00        48
#          613       1.00      1.00      1.00         6
#          617       1.00      1.00      1.00        70
#          640       1.00      1.00      1.00        43
#          819       1.00      1.00      1.00         8
#          870       1.00      1.00      1.00        56
#          873       1.00      1.00      1.00       116
#         1013       1.00      1.00      1.00        22
#         1158       1.00      1.00      1.00        10
#         1385       1.00      1.00      1.00       123
#         1439       1.00      1.00      1.00        43
#         1624       1.00      1.00      1.00        79
#         1715       1.00      1.00      1.00        27
#         1720       1.00      1.00      1.00        22
#         1851       1.00      1.00      1.00        64
#         2009       1.00      1.00      1.00        62
#         2031       1.00      1.00      1.00        60
#         2202       1.00      1.00      1.00        56
#         2774       1.00      1.00      1.00        14
#         3105       1.00      1.00      1.00        66
#         3916       1.00      1.00      1.00        67
#         5657       1.00      1.00      1.00        98
#
#     accuracy                           1.00      1617
#    macro avg       1.00      1.00      1.00      1617
# weighted avg       1.00      1.00      1.00      1617
#
# Mejor marca según Random Forest:
# Make                      Ford
# Predicted_Popularity    5657.0
# Name: 13, dtype: object
# Tres marcas más populares según Random Forest:
#     Make  Predicted_Popularity
# 13  Ford                5657.0
# 4    BMW                3916.0
# 3   Audi                3105.0

# %%
print("Mejores hiperparámetros para Random Forest:")
print(rf_random_search.best_params_)
# Out:
# Mejores hiperparámetros para Random Forest:
# {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 20, 'bootstrap': True}

# %%
# %matplotlib inline

def plot_learning_curve(estimator, title, X, y, cv=None, n_jobs=-1, train_sizes=np.linspace(0.1, 1.0, 10)):
    plt.figure()
    plt.title(title)
    plt.xlabel("Conjunto de entrenamiento")
    plt.ylabel("Puntuación")
    
    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.grid()
    
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1,
                     color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Entrenamiento")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Validación")
    
    plt.legend(loc="best")
    return plt

title = "Curva de aprendizaje - Random Forest"
cv = 3 

plot = plot_learning_curve(best_rf, title, X_train, y_train, cv=cv)
plt.show()
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   warnings.warn(
